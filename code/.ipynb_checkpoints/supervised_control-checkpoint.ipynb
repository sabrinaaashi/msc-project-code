# %%
import sys
import os
absFilePath = os.path.abspath('example_state_switching.py')
fileDir = os.path.dirname(absFilePath)
parentDir = os.path.dirname(fileDir)

import func_pytorch as functions
from opt_pytorch import FR_algorithm

import torch
import pickle
import matplotlib.pyplot as plt
from pylab import figure, cm


goal='sync'
bifurcation='high'
noise_strength= 0.0 
realizations=1
noise=0
parameters = functions.set_parameters(goal,bifurcation,parentDir)

# 10 nodes
n_nodes = 10
A = parameters['A'][:n_nodes,:n_nodes]
#A = np.zeros((5,5))
parameters['A'] = A
parameters['N'] = n_nodes


#Set dimensions
T= 400 #simulation and control time 
dt=0.1 #time stepsize
tsteps=int(T/dt) #number of timesteps
d=2 #dimension of each FitzHugh-Nagumo node

#set paraeters of the cost functional
I_p_in= 0.0005 #penalize precision
I_e= 1.0 #penalize control energy should be >0
I_s= 0.0#enforce sparsity

switchfromto='none'
I_p=I_p_in

#choose initial condition for control
control=-torch.ones((tsteps,parameters['N']))*0.002
control=control.reshape(tsteps*parameters['N'])

node_ic=functions.set_random_initial_conds_for_nodes(bifurcation,noise_strength,tsteps,d,dt,parameters,realizations,noise)

args = {
    'tsteps':tsteps,
    'dt':dt,
    'd':d,
    'I_p':I_p,
    'I_e':I_e,
    'I_s':I_s,
    #'target_output':target_output,
    'node_ic':node_ic,
    'realizations':realizations,
    'noise':noise
    }
args.update(parameters)

# %%
def create_plot(data,ylabel,title):
    fs=30 #fontsize
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

    # set min and max for scope of y-axis
    minn=torch.min(data)
    maxx=torch.max(data)
    add=(maxx-minn)/25

    im1=ax.plot(torch.arange(0,int(T),dt),data)
    ax.set_xlabel('t',size=fs)
    ax.set_ylabel(ylabel,size=fs)
    ax.set_ylim(minn-add,maxx+add)
    ax.set_title(title,size=fs, pad=20)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.margins(0) # remove default margins (matplotlib verision 2+)

    return fig.tight_layout()

# %%
def cross_correlation_matrix(x , horizen_length , N):
    means = (1/horizen_length) * torch.sum(x, dim=0)
    stds = torch.sqrt(torch.sum((x - means)**2, dim=0))
    stdsgrid = torch.ones((N, 1)) * stds
    stdsgrid = stdsgrid.transpose(0, 1) * stdsgrid
    xcc = x - means
    cross_correlation_mat = torch.matmul(xcc.transpose(0, 1), xcc) / stdsgrid

    return cross_correlation_mat

# %%
nocontrol=torch.zeros((tsteps,parameters['N']))
state_uncontrolled=functions.plot_runge_kutta(functions.ODE_FHN_network,nocontrol, **args)

# %%
create_plot(state_uncontrolled[:,0,:],'x1','sample')

# %%
sample_cc = cross_correlation_matrix(state_uncontrolled[:,0,:] , tsteps , args['N'])

# %%
print(sample_cc)
# Out:
# tensor([[1.0000, 0.9267, 0.5706, 0.4592, 0.4015, 0.2675, 0.7346, 0.4885, 0.5809,
#          0.6046],
#         [0.9267, 1.0000, 0.7806, 0.6941, 0.6418, 0.5225, 0.8901, 0.7194, 0.7842,
#          0.7976],
#         [0.5706, 0.7806, 1.0000, 0.9872, 0.9759, 0.9224, 0.9689, 0.9930, 0.9992,
#          0.9973],
#         [0.4592, 0.6941, 0.9872, 1.0000, 0.9959, 0.9705, 0.9191, 0.9990, 0.9821,
#          0.9754],
#         [0.4015, 0.6418, 0.9759, 0.9959, 1.0000, 0.9826, 0.8936, 0.9924, 0.9718,
#          0.9641],
#         [0.2675, 0.5225, 0.9224, 0.9705, 0.9826, 1.0000, 0.8037, 0.9592, 0.9138,
#          0.9015],
#         [0.7346, 0.8901, 0.9689, 0.9191, 0.8936, 0.8037, 1.0000, 0.9344, 0.9734,
#          0.9795],
#         [0.4885, 0.7194, 0.9930, 0.9990, 0.9924, 0.9592, 0.9344, 1.0000, 0.9887,
#          0.9830],
#         [0.5809, 0.7842, 0.9992, 0.9821, 0.9718, 0.9138, 0.9734, 0.9887, 1.0000,
#          0.9993],
#         [0.6046, 0.7976, 0.9973, 0.9754, 0.9641, 0.9015, 0.9795, 0.9830, 0.9993,
#          1.0000]])

# %%
import random
target_anticc = sample_cc.clone()
pairs = [(i, j) for i in range(10) for j in range(i+1, 10)]
selected_pairs = torch.tensor(random.sample(pairs, 10))

# Set the selected elements to -1
for i, j in selected_pairs:
    target_anticc[i, j] = target_anticc[j, i] = -1

print(target_anticc)
# Out:
# tensor([[ 1.0000,  0.9267,  0.5706, -1.0000,  0.4015,  0.2675,  0.7346, -1.0000,
#          -1.0000,  0.6046],
#         [ 0.9267,  1.0000,  0.7806,  0.6941,  0.6418,  0.5225,  0.8901, -1.0000,
#          -1.0000,  0.7976],
#         [ 0.5706,  0.7806,  1.0000,  0.9872,  0.9759,  0.9224,  0.9689,  0.9930,
#           0.9992,  0.9973],
#         [-1.0000,  0.6941,  0.9872,  1.0000,  0.9959,  0.9705,  0.9191,  0.9990,
#           0.9821,  0.9754],
#         [ 0.4015,  0.6418,  0.9759,  0.9959,  1.0000,  0.9826, -1.0000,  0.9924,
#          -1.0000, -1.0000],
#         [ 0.2675,  0.5225,  0.9224,  0.9705,  0.9826,  1.0000, -1.0000, -1.0000,
#           0.9138,  0.9015],
#         [ 0.7346,  0.8901,  0.9689,  0.9191, -1.0000, -1.0000,  1.0000,  0.9344,
#           0.9734,  0.9795],
#         [-1.0000, -1.0000,  0.9930,  0.9990,  0.9924, -1.0000,  0.9344,  1.0000,
#           0.9887,  0.9830],
#         [-1.0000, -1.0000,  0.9992,  0.9821, -1.0000,  0.9138,  0.9734,  0.9887,
#           1.0000,  0.9993],
#         [ 0.6046,  0.7976,  0.9973,  0.9754, -1.0000,  0.9015,  0.9795,  0.9830,
#           0.9993,  1.0000]])

# %%
target_output = target_anticc
args['target_output'] = target_output

# %%
control=-torch.ones((tsteps,parameters['N']))*0.002
control=control.reshape(tsteps*parameters['N'])

functional=functions.f_sync
gradient=functions.fprime_sync

from opt_pytorch import FR_algorithm
#initialize the control loop
iteration=0 
#warnflag=1-> running, warnflag=0->finished, warnflag=3->error
warnflag=1
#start the optmization
while warnflag == 1 and iteration<5000:
    
    result = FR_algorithm(functional, control, gradient,**args)

    control=result[0]
    warnflag=result[2]
    iteration+=result[4]
    
    #make dictionary to save the result
    out={
        'optimal_control':control.reshape(tsteps,parameters['N']),
        'functional':result[1],
        'gradient_norm':result[3],
        'warnflag':result[2],
        'iterations':iteration,
        'node_ic':node_ic,
        'target_output':target_output,
        'external_current':parameters['mu'],
        'coupling_strength':parameters['sigma'],
        'noise_strength':noise_strength,
        'noise':noise,
        'I_p':I_p,
        'I_e':I_e,
        'I_s':I_s,
        'T':T,
        'bifurcation':bifurcation,
        'goal':goal
        }
    
    print('Iteration ',iteration,' finished at gnorm',result[3],'with f',result[1],'with warnflag',result[2])
print('Code finished after ',iteration,' iterations with warnflag',result[2])
# Out:
# tensor([0.0021, 0.0019, 0.0008,  ..., 0.0011, 0.0011, 0.0011],
#        grad_fn=<AddBackward0>) tensor(0.0363, grad_fn=<AddBackward0>) tensor([0.0022, 0.0019, 0.0005,  ..., 0.0011, 0.0011, 0.0011],
#        grad_fn=<ReshapeAliasBackward0>)
# tensor([0.0021, 0.0019, 0.0008,  ..., 0.0011, 0.0011, 0.0011],
#        grad_fn=<AddBackward0>) tensor(0.0363, grad_fn=<AddBackward0>) tensor([0.0022, 0.0019, 0.0005,  ..., 0.0011, 0.0011, 0.0011],
#        grad_fn=<ReshapeAliasBackward0>)

# %%
import sys
import os
absFilePath = os.path.abspath('example_state_switching.py')
fileDir = os.path.dirname(absFilePath)
parentDir = os.path.dirname(fileDir)

import functions as functions
from FRoptimize import FR_algorithm

import numpy as np
import pickle
import matplotlib.pyplot as plt
from pylab import figure, cm

goal='sync'
bifurcation='high'
noise_strength= 0.0 
realizations=1
noise=0
parameters = functions.set_parameters(goal,bifurcation,parentDir)

# 10 nodes
n_nodes = 10
A = parameters['A'][:n_nodes,:n_nodes]
parameters['A'] = A
parameters['N'] = n_nodes


#Set dimensions
T= 400 #simulation and control time 
dt=0.1 #time stepsize
tsteps=int(T/dt) #number of timesteps
d=2 #dimension of each FitzHugh-Nagumo node

#set paraeters of the cost functional
I_p_in= 0.0005 #penalize precision
I_e= 1.0 #penalize control energy should be >0
I_s= 0.0#enforce sparsity

switchfromto='none'
I_p=I_p_in

#choose initial condition for control
control=-np.ones((tsteps,parameters['N']))*0.002
control=control.reshape(tsteps*parameters['N'])

node_ic=functions.set_random_initial_conds_for_nodes(bifurcation,noise_strength,tsteps,d,dt,parameters,realizations,noise)
#ic_state_high=functions.set_random_initial_conds_for_nodes('high',noise_strength,tsteps,d,dt,parameters_high,realizations,noise)
target_output=np.ones((parameters['N'],parameters['N']))

args = {
    'tsteps':tsteps,
    'dt':dt,
    'd':d,
    'I_p':I_p,
    'I_e':I_e,
    'I_s':I_s,
    'target_output':target_output,
    'node_ic':node_ic,
    'realizations':realizations,
    'noise':noise
    }
args.update(parameters)
# Out:
# /Users/shi/Desktop/individual/OptimalControl-master/src_and_example/functions.py:848: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   k1 = dt* ODE_FHN_network(x[ts],ts,control,tsteps , d , dt , N , alpha , beta, gamma, delta, epsilon, tau, mu ,sigma, A)
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
#In this case we want to find an optimal control that induces a switching 
#from an initial low state to a high target state. The uncontrolled state and 
#the target state are plotted:

def create_plot(data,ylabel):
    fs=10 #fontsize
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))

    # set min and max for scope of y-axis
    minn=np.min(data)
    maxx=np.max(data)
    add=(maxx-minn)/25

    im1=ax.plot(np.arange(0,int(T),dt),data)
    ax.set_xlabel('t',size=fs)
    ax.set_ylabel(ylabel,size=fs)
    ax.set_ylim(minn-add,maxx+add)
    #ax.set_title(title,size=fs, pad=20)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.margins(0) # remove default margins (matplotlib verision 2+)

    return fig.tight_layout()

# %%
nocontrol=np.zeros((tsteps,parameters['N']))
state_uncontrolled=functions.plot_runge_kutta(functions.ODE_FHN_network,nocontrol, **args)

create_plot(state_uncontrolled[:,0,:],'activity $x_{1}$')
plt.show()

# %%
def cross_correlation_matrix(x , tsteps , N):
    means = (1/tsteps) * np.sum(x,axis=0)
    stds =  ((x-means)**2).sum(axis=0)**(1/2) 
    stdsgrid= np.ones((N,1))*stds
    stdsgrid= stdsgrid.transpose()*stdsgrid
    xcc = (x-means)
    cross_correlation_mat= np.dot(xcc.transpose(), xcc)/stdsgrid

    return cross_correlation_mat

# %%
sample_cc = cross_correlation_matrix(state_uncontrolled[:,0,:], tsteps , n_nodes)

# %%
print(sample_cc)
# Out:
# [[ 1.         -0.09956878  0.98751929  0.96213801  0.81311472  0.97708691
#    0.81013018  0.84625693  0.78620484  0.96084571]
#  [-0.09956878  1.         -0.03182841 -0.17320104 -0.15543377 -0.20783613
#   -0.17057965 -0.17452298 -0.16504831 -0.24791467]
#  [ 0.98751929 -0.03182841  1.          0.91407088  0.83918993  0.9386578
#    0.83201532  0.78421748  0.81213626  0.92191634]
#  [ 0.96213801 -0.17320104  0.91407088  1.          0.67735647  0.96556371
#    0.67837796  0.94771041  0.64946614  0.94372317]
#  [ 0.81311472 -0.15543377  0.83918993  0.67735647  1.          0.81722784
#    0.99884441  0.46939461  0.99825247  0.84068811]
#  [ 0.97708691 -0.20783613  0.9386578   0.96556371  0.81722784  1.
#    0.82196638  0.84149443  0.79612098  0.99515224]
#  [ 0.81013018 -0.17057965  0.83201532  0.67837796  0.99884441  0.82196638
#    1.          0.46848708  0.99859235  0.84755091]
#  [ 0.84625693 -0.17452298  0.78421748  0.94771041  0.46939461  0.84149443
#    0.46848708  1.          0.43937138  0.80691221]
#  [ 0.78620484 -0.16504831  0.81213626  0.64946614  0.99825247  0.79612098
#    0.99859235  0.43937138  1.          0.82291654]
#  [ 0.96084571 -0.24791467  0.92191634  0.94372317  0.84068811  0.99515224
#    0.84755091  0.80691221  0.82291654  1.        ]]

# %%
import random
target_anticc = sample_cc.copy()
pairs = [(i, j) for i in range(10) for j in range(i+1, 10)]
selected_pairs = random.sample(pairs, 10)

# Set the selected elements to -1
for i, j in selected_pairs:
    target_anticc[i, j] = target_anticc[j, i] = -1

print(target_anticc)
# Out:
# [[ 1.         -0.09956878 -1.         -1.          0.81311472 -1.
#    0.81013018  0.84625693  0.78620484  0.96084571]
#  [-0.09956878  1.         -1.         -0.17320104 -0.15543377 -0.20783613
#   -0.17057965 -0.17452298 -0.16504831 -0.24791467]
#  [-1.         -1.          1.          0.91407088 -1.         -1.
#    0.83201532  0.78421748 -1.          0.92191634]
#  [-1.         -0.17320104  0.91407088  1.          0.67735647  0.96556371
#    0.67837796  0.94771041  0.64946614  0.94372317]
#  [ 0.81311472 -0.15543377 -1.          0.67735647  1.          0.81722784
#   -1.          0.46939461  0.99825247  0.84068811]
#  [-1.         -0.20783613 -1.          0.96556371  0.81722784  1.
#   -1.          0.84149443  0.79612098  0.99515224]
#  [ 0.81013018 -0.17057965  0.83201532  0.67837796 -1.         -1.
#    1.          0.46848708  0.99859235  0.84755091]
#  [ 0.84625693 -0.17452298  0.78421748  0.94771041  0.46939461  0.84149443
#    0.46848708  1.         -1.          0.80691221]
#  [ 0.78620484 -0.16504831 -1.          0.64946614  0.99825247  0.79612098
#    0.99859235 -1.          1.          0.82291654]
#  [ 0.96084571 -0.24791467  0.92191634  0.94372317  0.84068811  0.99515224
#    0.84755091  0.80691221  0.82291654  1.        ]]

# %%
target_output = target_anticc
args['target_output'] = target_output

# %%
functional=functions.f_sync
gradient=functions.fprime_sync

#initialize the control loop
iteration=0 
#warnflag=1-> running, warnflag=0->finished, warnflag=3->error
warnflag=1
#start the optmization
result = FR_algorithm(functional, control, gradient, max_k=1000, **args)
control=result[0]
warnflag=result[2]
iteration+=result[4]
print('Code finished after ',iteration,' iterations with warnflag',result[2])
# Out:
# gnorm 9.622042549523903e-05 uknorm 4.723157339780624e-06
# Code finished after  39  iterations with warnflag 0

# %%
#The results can now be plottet:

#calculate the controlled state
control=control.reshape(tsteps,parameters['N'])
state_controlled=functions.plot_runge_kutta(functions.ODE_FHN_network,control, **args)

create_plot(state_controlled[:,0,:],'axtivity $x_{1}$')
plt.show()
create_plot(control,'control $u_{1}$')
plt.show()

# %%
controlled_cc = cross_correlation_matrix(state_controlled[:,0,:], tsteps , n_nodes)

# %%
print(controlled_cc)
# Out:
# [[ 1.         -0.00831759  0.03760223  0.46461769  0.85816014  0.64229083
#    0.91938996  0.33075601  0.94426414  0.77956062]
#  [-0.00831759  1.         -0.28460725 -0.21316093 -0.22516466 -0.19020587
#   -0.07623688 -0.2223696  -0.06364201 -0.17932315]
#  [ 0.03760223 -0.28460725  1.          0.62761994  0.12195261  0.41363122
#   -0.15568146  0.74822204 -0.1445763   0.24338326]
#  [ 0.46461769 -0.21316093  0.62761994  1.          0.69819221  0.94193602
#    0.22011356  0.97313003  0.289191    0.8318634 ]
#  [ 0.85816014 -0.22516466  0.12195261  0.69819221  1.          0.86144431
#    0.74529874  0.55671744  0.80955226  0.95559197]
#  [ 0.64229083 -0.19020587  0.41363122  0.94193602  0.86144431  1.
#    0.43235495  0.84398075  0.50885886  0.96255202]
#  [ 0.91938996 -0.07623688 -0.15568146  0.22011356  0.74529874  0.43235495
#    1.          0.08213133  0.99008678  0.60073364]
#  [ 0.33075601 -0.2223696   0.74822204  0.97313003  0.55671744  0.84398075
#    0.08213133  1.          0.14256206  0.6976115 ]
#  [ 0.94426414 -0.06364201 -0.1445763   0.289191    0.80955226  0.50885886
#    0.99008678  0.14256206  1.          0.67581982]
#  [ 0.77956062 -0.17932315  0.24338326  0.8318634   0.95559197  0.96255202
#    0.60073364  0.6976115   0.67581982  1.        ]]

# %%
print(np.sum((target_anticc-sample_cc)**2), np.sum((target_anticc-controlled_cc)**2))
# Out:
# 64.91605862343408 38.92115799864396

# %%
#random intial condition
node_ic=functions.set_random_initial_conds_for_nodes(bifurcation,noise_strength,tsteps,d,dt,parameters,realizations,noise)
args['node_ic'] = node_ic
#initialize the control loop
iteration=0 
#warnflag=1-> running, warnflag=0->finished, warnflag=3->error
warnflag=1
#start the optmization
result = FR_algorithm(functional, control, gradient, max_k=1000, **args)
control=result[0]
warnflag=result[2]
iteration+=result[4]
print('Code finished after ',iteration,' iterations with warnflag',result[2])

control=control.reshape(tsteps,parameters['N'])
state_controlled=functions.plot_runge_kutta(functions.ODE_FHN_network,control, **args)
nocontrol=np.zeros((tsteps,parameters['N']))
state_uncontrolled=functions.plot_runge_kutta(functions.ODE_FHN_network,nocontrol, **args)

# %%
# Initialize lists to store results for all iterations
all_controls = []
all_states_controlled = []
all_states_uncontrolled = []

functional=functions.f_sync
gradient=functions.fprime_sync
# Repeat the process 100 times
for _ in range(100):
    # Random initial condition
    node_ic = functions.set_random_initial_conds_for_nodes(bifurcation, noise_strength, tsteps, d, dt, parameters, realizations, noise)
    args['node_ic'] = node_ic
    #choose initial condition for control
    control=-np.ones((tsteps,parameters['N']))*0.002
    control=control.reshape(tsteps*parameters['N'])
    
    # Initialize the control loop
    iteration = 0 
    # warnflag=1-> running, warnflag=0->finished, warnflag=3->error
    warnflag = 1
    
    # Start the optimization
    result = FR_algorithm(functional, control, gradient, max_k=1000, **args)
    control = result[0]
    warnflag = result[2]
    iteration += result[4]
    print('Code finished after ', iteration, ' iterations with warnflag', result[2])
    
    control = control.reshape(tsteps, parameters['N'])
    state_controlled = functions.plot_runge_kutta(functions.ODE_FHN_network, control, **args)
    nocontrol = np.zeros((tsteps, parameters['N']))
    state_uncontrolled = functions.plot_runge_kutta(functions.ODE_FHN_network, nocontrol, **args)
    
    # Store results
    all_controls.append(control)
    all_states_controlled.append(state_controlled)
    all_states_uncontrolled.append(state_uncontrolled)
# Out:
# gnorm 5.928331259568437e-05 uknorm 2.5501646841308637e-05
# Code finished after  33  iterations with warnflag 0
# gnorm 3.827082794686902e-05 uknorm 3.98653321961092e-06
# Code finished after  107  iterations with warnflag 0
# gnorm 9.372115944975088e-05 uknorm 5.073209449192985e-06
# Code finished after  50  iterations with warnflag 0
# gnorm 9.247880033503436e-05 uknorm 3.430337160998786e-06
# Code finished after  98  iterations with warnflag 0
# gnorm 9.806865177449655e-05 uknorm 3.980912964020138e-06
# Code finished after  56  iterations with warnflag 0
# gnorm 6.142895180671643e-05 uknorm 7.66604409051198e-06
# Code finished after  131  iterations with warnflag 0
# gnorm 8.720994252289782e-05 uknorm 1.2353065767417007e-05
# Code finished after  32  iterations with warnflag 0
# gnorm 5.6534033202150784e-05 uknorm 3.876271869729733e-06
# Code finished after  117  iterations with warnflag 0
# gnorm 8.277751947220117e-05 uknorm 2.5406179543689764e-06
# Code finished after  73  iterations with warnflag 0
# gnorm 6.591723141230281e-05 uknorm 1.0003265958361419e-05
# Code finished after  33  iterations with warnflag 0
# gnorm 5.390184709560132e-05 uknorm 2.2662072598480295e-05
# Code finished after  46  iterations with warnflag 0
# gnorm 9.818972255163104e-05 uknorm 1.9902908656787427e-05
# Code finished after  17  iterations with warnflag 0
# gnorm 0.0001005633724163544 uknorm 6.95237381236947e-06
# Code finished after  42  iterations with warnflag 0
# gnorm 7.949247800890136e-05 uknorm 9.410183850996987e-06
# Code finished after  67  iterations with warnflag 0
# gnorm 9.36521802986373e-05 uknorm 2.891073364481205e-05
# Code finished after  54  iterations with warnflag 0
# gnorm 5.8888042849165835e-05 uknorm 9.781283936770302e-06
# Code finished after  37  iterations with warnflag 0
# gnorm 8.624461494974377e-05 uknorm 3.5767512114787993e-06
# Code finished after  81  iterations with warnflag 0
# gnorm 6.0727377697041614e-05 uknorm 1.2108875066460306e-05
# Code finished after  47  iterations with warnflag 0
# gnorm 9.166133914889044e-05 uknorm 1.0462603901863123e-05
# Code finished after  59  iterations with warnflag 0
# gnorm 5.663292737462418e-05 uknorm 3.831743904199889e-06
# Code finished after  96  iterations with warnflag 0
# gnorm 8.891414399340037e-05 uknorm 2.9572242000205744e-06
# Code finished after  52  iterations with warnflag 0
# gnorm 4.01012466140565e-05 uknorm 1.1746417448139186e-05
# Code finished after  25  iterations with warnflag 0
# gnorm 8.177735148199553e-05 uknorm 2.9592300649927423e-06
# Code finished after  56  iterations with warnflag 0
# gnorm 9.462898838429805e-05 uknorm 3.3208125551553377e-06
# Code finished after  72  iterations with warnflag 0
# gnorm 8.984359689372595e-05 uknorm 0.000141388693762429
# Code finished after  16  iterations with warnflag 0
# gnorm 9.95162831048395e-05 uknorm 2.986036520407319e-06
# Code finished after  66  iterations with warnflag 0
# gnorm 6.336585246229983e-05 uknorm 1.9082240214829925e-05
# Code finished after  30  iterations with warnflag 0
# gnorm 9.736267645012826e-05 uknorm 3.5370530726542156e-05
# Code finished after  74  iterations with warnflag 0
# gnorm 9.237009888853e-05 uknorm 8.960039683916657e-06
# Code finished after  28  iterations with warnflag 0
# gnorm 9.714348855954826e-05 uknorm 5.243753031595718e-05
# Code finished after  25  iterations with warnflag 0
# gnorm 8.630792725680095e-05 uknorm 7.5872536578105564e-06
# Code finished after  39  iterations with warnflag 0
# gnorm 4.6799755518705036e-05 uknorm 7.5105619957389685e-06
# Code finished after  60  iterations with warnflag 0
# gnorm 9.955506802037718e-05 uknorm 3.379869529170857e-06
# Code finished after  62  iterations with warnflag 0
# gnorm 9.616683376859948e-05 uknorm 7.24236628436689e-05
# Code finished after  30  iterations with warnflag 0
# gnorm 9.565999957005574e-05 uknorm 7.958518050750268e-06
# Code finished after  75  iterations with warnflag 0
# gnorm 7.393410051684951e-05 uknorm 2.6309851331315307e-06
# Code finished after  46  iterations with warnflag 0
# gnorm 0.00010024297309500145 uknorm 8.066502570541322e-06
# Code finished after  155  iterations with warnflag 0
# gnorm 9.210051580895362e-05 uknorm 4.237772960639756e-06
# Code finished after  53  iterations with warnflag 0
# gnorm 9.954749960941825e-05 uknorm 4.9162971529183655e-06
# Code finished after  35  iterations with warnflag 0
# Bisection: minimal alphastep or max iteration reached: 5.421010862427522e-18
# Bisection: minimal alphastep or max iteration reached: 6.5052130349130266e-18
# Problem with the linesearch.
# Code finished after  63  iterations with warnflag 3
# gnorm 8.550673820729497e-05 uknorm 2.3847986192657286e-05
# Code finished after  46  iterations with warnflag 0
# gnorm 7.514470906050597e-05 uknorm 3.1479818768023055e-06
# Code finished after  59  iterations with warnflag 0
# gnorm 6.883636930301142e-05 uknorm 2.2329052591161863e-05
# Code finished after  30  iterations with warnflag 0
# gnorm 7.626511925543783e-05 uknorm 4.4330498009039996e-05
# Code finished after  63  iterations with warnflag 0
# gnorm 9.547683459122014e-05 uknorm 7.707029064000365e-06
# Code finished after  47  iterations with warnflag 0
# gnorm 9.887777533094423e-05 uknorm 1.647348784754028e-05
# Code finished after  41  iterations with warnflag 0
# gnorm 9.494846906843999e-05 uknorm 1.6088195496416404e-05
# Code finished after  46  iterations with warnflag 0
# gnorm 7.57328621756358e-05 uknorm 2.344581840024989e-06
# Code finished after  58  iterations with warnflag 0
# gnorm 8.898483644518282e-05 uknorm 1.1956296132711918e-05
# Code finished after  37  iterations with warnflag 0
# gnorm 6.373089535914329e-05 uknorm 2.7002953930052066e-06
# Code finished after  70  iterations with warnflag 0
# gnorm 9.262826189514195e-05 uknorm 3.139234392043823e-05
# Code finished after  25  iterations with warnflag 0
# gnorm 8.351306021888208e-05 uknorm 5.951833764076143e-06
# Code finished after  67  iterations with warnflag 0
# gnorm 9.085322708867914e-05 uknorm 4.388629206790321e-06
# Code finished after  78  iterations with warnflag 0
# gnorm 7.910814430497701e-05 uknorm 7.908369086921229e-06
# Code finished after  59  iterations with warnflag 0
# gnorm 7.124949309822811e-05 uknorm 8.31831725782873e-06
# Code finished after  238  iterations with warnflag 0
# gnorm 9.098943602626423e-05 uknorm 7.803350037529798e-06
# Code finished after  34  iterations with warnflag 0
# gnorm 0.00010033708859268249 uknorm 5.434549098140612e-05
# Code finished after  26  iterations with warnflag 0
# gnorm 8.428907750346565e-05 uknorm 2.0914639217601942e-05
# Code finished after  19  iterations with warnflag 0
# gnorm 9.933114199339472e-05 uknorm 2.1951012353980774e-06
# Code finished after  68  iterations with warnflag 0
# gnorm 6.752491023171814e-05 uknorm 6.684745820598171e-06
# Code finished after  37  iterations with warnflag 0
# gnorm 8.238200939761982e-05 uknorm 2.691592334321544e-06
# Code finished after  83  iterations with warnflag 0
# gnorm 8.945912183462237e-05 uknorm 2.098045663178553e-05
# Code finished after  44  iterations with warnflag 0
# gnorm 4.9447979842605913e-05 uknorm 0.00010882551119921458
# Code finished after  40  iterations with warnflag 0
# gnorm 6.007264722192622e-05 uknorm 3.3902178639213815e-06
# Code finished after  66  iterations with warnflag 0
# gnorm 5.436147391824466e-05 uknorm 3.312307951288708e-06
# Code finished after  69  iterations with warnflag 0
# gnorm 6.32777551862764e-05 uknorm 5.926536331508133e-06
# Code finished after  36  iterations with warnflag 0
# gnorm 7.276150156711528e-05 uknorm 2.095173403198619e-06
# Code finished after  90  iterations with warnflag 0
# gnorm 9.479314615325933e-05 uknorm 3.705201076303075e-06
# Code finished after  68  iterations with warnflag 0
# gnorm 7.382945578251923e-05 uknorm 6.0250109916505125e-06
# Code finished after  99  iterations with warnflag 0
# gnorm 8.313483173617441e-05 uknorm 7.5409160161254724e-06
# Code finished after  65  iterations with warnflag 0
# gnorm 7.779988895927352e-05 uknorm 4.588913481345285e-05
# Code finished after  66  iterations with warnflag 0
# gnorm 7.30340548647393e-05 uknorm 1.6895403422310918e-05
# Code finished after  51  iterations with warnflag 0
# gnorm 5.001071177156624e-05 uknorm 4.689635367072101e-06
# Code finished after  71  iterations with warnflag 0
# gnorm 8.483004268656027e-05 uknorm 2.2217468811373234e-05
# Code finished after  17  iterations with warnflag 0
# gnorm 9.057528946295238e-05 uknorm 3.993614474969483e-06
# Code finished after  62  iterations with warnflag 0
# gnorm 6.92961911579091e-05 uknorm 8.175301989332869e-06
# Code finished after  38  iterations with warnflag 0
# gnorm 8.734492880572878e-05 uknorm 2.0480219831843288e-05
# Code finished after  65  iterations with warnflag 0
# gnorm 9.494146785487363e-05 uknorm 1.2219661109294858e-05
# Code finished after  46  iterations with warnflag 0
# gnorm 5.4551361480303494e-05 uknorm 3.7739804116467164e-06
# Code finished after  79  iterations with warnflag 0
# gnorm 9.829663402047056e-05 uknorm 3.9834141486823e-06
# Code finished after  65  iterations with warnflag 0
# gnorm 8.869668861823522e-05 uknorm 1.0915009249050107e-05
# Code finished after  36  iterations with warnflag 0
# gnorm 6.968618606986936e-05 uknorm 1.0755594213096575e-05
# Code finished after  31  iterations with warnflag 0
# gnorm 6.590882704326834e-05 uknorm 8.071010370105377e-05
# Code finished after  15  iterations with warnflag 0
# gnorm 7.61314450973224e-05 uknorm 5.930709486118638e-06
# Code finished after  49  iterations with warnflag 0
# gnorm 8.95974952238402e-05 uknorm 2.7376559227839563e-05
# Code finished after  27  iterations with warnflag 0
# gnorm 7.995336479416667e-05 uknorm 3.950110650296395e-06
# Code finished after  64  iterations with warnflag 0
# gnorm 9.938233778314175e-05 uknorm 2.689299650368858e-05
# Code finished after  31  iterations with warnflag 0
# gnorm 8.445136701773536e-05 uknorm 2.9938917300502237e-06
# Code finished after  62  iterations with warnflag 0
# gnorm 0.00010006989991880169 uknorm 4.330405905356933e-05
# Code finished after  32  iterations with warnflag 0
# gnorm 8.714981229534396e-05 uknorm 2.76746976574831e-06
# Code finished after  87  iterations with warnflag 0
# gnorm 9.051504497128602e-05 uknorm 3.562983308689604e-06
# Code finished after  98  iterations with warnflag 0
# gnorm 7.334192772659302e-05 uknorm 7.418632232724211e-06
# Code finished after  42  iterations with warnflag 0
# gnorm 5.8989943008449716e-05 uknorm 2.7337621801362677e-06
# Code finished after  79  iterations with warnflag 0
# gnorm 9.698048652212053e-05 uknorm 1.4759419747013445e-05
# Code finished after  37  iterations with warnflag 0
# gnorm 9.509259553783602e-05 uknorm 4.046587425888919e-06
# Code finished after  62  iterations with warnflag 0
# gnorm 7.027843545622013e-05 uknorm 3.85035796015773e-06
# Code finished after  67  iterations with warnflag 0
# gnorm 9.034465055510936e-05 uknorm 1.4978733283486359e-05
# Code finished after  61  iterations with warnflag 0
# gnorm 5.371271951784334e-05 uknorm 3.1941618365228987e-06
# Code finished after  65  iterations with warnflag 0
# gnorm 4.654529056642546e-05 uknorm 4.7671592139073016e-05
# Code finished after  22  iterations with warnflag 0
# gnorm 6.994946208135346e-05 uknorm 1.4854198251146962e-05
# Code finished after  39  iterations with warnflag 0

# %%
all_states_uncontrolled[0].shape
# Out:
# (4000, 2, 10)

# %%
all_controls[0].shape
# Out:
# (4000, 10)

# %%
len(all_controls)
# Out:
# 100

# %%
from sklearn.linear_model import LinearRegression

# Reshape data
X = np.vstack(all_states_uncontrolled)  # Stack all matrices vertically
y = np.vstack(all_controls)  # Stack and flatten control arrays

# Split the data into train and test (optional but recommended)
from sklearn.model_selection import train_test_split

# Reshape X to be 2D
X_reshaped = X.reshape(-1, 2 * 10)  # Flatten the last two dimensions

# Interleave rows in X to match with y
X_interleaved = np.vstack([X_reshaped[i::2] for i in range(2)])
print(X_interleaved.shape,y.shape)
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_interleaved, y, test_size=0.2, random_state=42)

# Train the linear regressor
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predict on test set (optional)
y_pred = regressor.predict(X_test)

# Evaluate the performance (optional)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on test set: {mse:.10f}")
# Out:
# (400000, 20) (400000, 10)
# Mean Squared Error on test set: 0.0000000809

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared value: {r2:.2f}")
# Out:
# R-squared value: 0.01

# %%
import matplotlib.pyplot as plt

residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.title('Residuals vs. Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Create polynomial features (let's try a 2nd degree polynomial as an example)
poly = PolynomialFeatures(degree=4)

# Create a pipeline that first creates polynomial features, then applies linear regression
model = make_pipeline(poly, LinearRegression())

# Fit the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred_poly = model.predict(X_test)

# Evaluate the performance
mse_poly = mean_squared_error(y_test, y_pred_poly)
print(f"Mean Squared Error on test set with polynomial regression: {mse_poly:.10f}")

# You can also get R^2 value for the polynomial regression
r2_poly = model.score(X_test, y_test)
print(f"R^2 value for polynomial regression: {r2_poly:.5f}")

# %%
all_controls[0]
# Out:
# array([[-1.88631439e-05, -2.78233869e-04, -4.61789794e-05, ...,
#          2.43252297e-06, -4.24443778e-05, -2.70788247e-06],
#        [-2.49539340e-05, -3.00650846e-04, -4.62618903e-05, ...,
#          1.47373980e-06, -4.28318098e-05, -2.82786961e-06],
#        [-3.14103319e-05, -3.23896706e-04, -4.62854207e-05, ...,
#          4.45804094e-07, -4.31934028e-05, -2.95096996e-06],
#        ...,
#        [-4.53822935e-07,  1.02613285e-07,  6.13495542e-08, ...,
#         -2.89547421e-07,  1.15631102e-07, -1.03460997e-07],
#        [-2.23373203e-07,  5.31594264e-08,  3.15981140e-08, ...,
#         -1.43102448e-07,  5.88219379e-08, -5.17510549e-08],
#        [-9.59974604e-11, -9.59974604e-11, -9.59974604e-11, ...,
#         -9.59974604e-11, -9.59974604e-11, -9.59974604e-11]])

# %%
all_controls[1]
# Out:
# array([[-5.07525398e-05,  1.87140100e-05,  1.99564380e-04, ...,
#          1.54660399e-04,  1.22376976e-05,  4.89696162e-04],
#        [-4.90816576e-05,  1.87460041e-05,  1.92751594e-04, ...,
#          1.30250521e-04,  1.16131651e-05,  4.68632892e-04],
#        [-4.75132110e-05,  1.87785380e-05,  1.86357089e-04, ...,
#          1.05916749e-04,  1.10202209e-05,  4.47143519e-04],
#        ...,
#        [-1.82239221e-07, -5.03504608e-07,  6.73474291e-07, ...,
#         -1.68858458e-07, -3.33889252e-07, -2.82985822e-07],
#        [-1.56355429e-07, -3.13042673e-07,  2.69286415e-07, ...,
#         -1.52035942e-07, -2.32695399e-07, -2.10124293e-07],
#        [-1.32108997e-07, -1.32108997e-07, -1.32108997e-07, ...,
#         -1.32108997e-07, -1.32108997e-07, -1.32108997e-07]])

# %%
print(all_controls[1].shape,y_pred.shape)
# Out:
# (4000, 10) (80000, 10)

# %%
create_plot(all_controls[1],'axtivity $x_{1}$')
plt.show()
create_plot(all_controls[0],'control $u_{1}$')
plt.show()
create_plot(y_pred[:4000,:],'control $u_{1}$')
plt.show()
create_plot(y_test[:4000,:],'control $u_{1}$')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Reshape data
X = np.vstack(all_states_uncontrolled)  # Stack all matrices vertically
y = np.vstack(all_controls)  # Stack and flatten control arrays

# Split the data into train and test (optional but recommended)
from sklearn.model_selection import train_test_split

# Reshape X to be 2D
X_reshaped = X.reshape(-1, 2 * 10)  # Flatten the last two dimensions

# Interleave rows in X to match with y
X_interleaved = np.vstack([X_reshaped[i::2] for i in range(2)])
print(X_interleaved.shape,y.shape)
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_interleaved, y, test_size=0.2,shuffle=False)

# Train the linear regressor
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predict on test set (optional)
y_pred = regressor.predict(X_test)

# Evaluate the performance (optional)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on test set: {mse:.10f}")
# Out:
# (400000, 20) (400000, 10)
# Mean Squared Error on test set: 0.0000000773

# %%
create_plot(y_pred[:4000,:],'control $u_{1}$')
plt.show()
create_plot(y_test[:4000,:],'control $u_{1}$')
plt.show()

# %%
#In this case we want to find an optimal control that induces a switching 
#from an initial low state to a high target state. The uncontrolled state and 
#the target state are plotted:

def create_plot(data,ylabel):
    fs=10 #fontsize
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))

    # set min and max for scope of y-axis
    minn=np.min(data)
    maxx=np.max(data)
    add=(maxx-minn)/25

    im1=ax.plot(np.arange(0,int(T),dt),data)
    ax.set_xlabel('t',size=fs)
    ax.set_ylabel(ylabel,size=fs)
    ax.set_ylim(minn-add,maxx+add)
    #ax.set_title(title,size=fs, pad=20)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.margins(0) # remove default margins (matplotlib verision 2+)

    return fig.tight_layout()

# %%
def create_plot(data,ylabel):
    fs=30 #fontsize
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

    # set min and max for scope of y-axis
    minn=np.min(data)
    maxx=np.max(data)
    add=(maxx-minn)/25

    im1=ax.plot(np.arange(0,int(T),dt),data)
    ax.set_xlabel('t',size=fs)
    ax.set_ylabel(ylabel,size=fs)
    ax.set_ylim(minn-add,maxx+add)
    ax.tick_params(labelsize=fs)
    ax.grid(True)
    ax.margins(0) # remove default margins (matplotlib verision 2+)

    return fig.tight_layout()
